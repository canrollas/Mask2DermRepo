# %%
import os
os.chdir("/content/Mask2DermRepo")

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 4.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python data/download.py --download-ham
# Out:
# Kaggle credentials not found (~/.kaggle/kaggle.json).
# You can create an API token at: https://www.kaggle.com/settings → API → Create New Token
#
# Kaggle username: rollas
# Kaggle API key:
# Credentials saved to /root/.kaggle/kaggle.json
#
# ...
# Dataset URL: https://www.kaggle.com/datasets/surajghuwalewala/ham1000-segmentation-and-classification
# License(s): Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)
# ...
# 100% 2.59G/2.59G [01:14<00:00, 37.4MB/s]
#
# HAM10000 download complete → data/raw/ham10000

# %%
# !python data/download.py --prepare --size 512
# Out:
# Processing 0 ISIC 2018 images…
# 0img [00:00, ?img/s]
# Processing 10015 HAM10000 entries…
# 100% 10015/10015 [02:23<00:00, 70.03img/s]
#
# Dataset prepared: 10015 samples → data/processed
# benign_malignant
# benign       8061
# malignant    1954

# %%
# !pip install xformers --quiet
import xformers
print(xformers.__version__)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.6 MB/s eta 0:00:00
# 0.0.35

# %%
# !accelerate launch train.py --config configs/train_config.yaml --resume-from-checkpoint /content/drive/MyDrive/Mask2DermRepo/outputs/checkpoints/checkpoint-epoch-0029
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# tokenizer_config.json: 100% 737/737 [00:00<00:00, 8.35MB/s]
# vocab.json: 1.06MB [00:00, 63.9MB/s]
# merges.txt: 525kB [00:00, 194MB/s]
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 6.43MB/s]
# tokenizer_config.json: 100% 725/725 [00:00<00:00, 9.97MB/s]
# special_tokens_map.json: 100% 460/460 [00:00<00:00, 6.24MB/s]
# config.json: 100% 560/560 [00:00<00:00, 2.23MB/s]
# text_encoder/model.safetensors: 100% 492M/492M [00:02<00:00, 222MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 1239.17it/s, Materializing param=text_model.final_layer_norm.weight]
# ...

# %%
# !python inference.py --controlnet /content/drive/MyDrive/Mask2DermRepo/outputs/checkpoints/checkpoint-best --mask /content/drive/MyDrive/Mask2DermRepo/vae_masks/mask_00004.png --controlnet_scale 1.2 --guidance_scale 12.0 --prompt "dermoscopy image of melanoma skin lesion, clinical photography, high quality dark color lesion. Hairy skin hairs,brown long skin hairs on the lesion. Blood vessels on the skin not on the lesion itself. "
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading pipeline from /content/drive/MyDrive/Mask2DermRepo/outputs/checkpoints/checkpoint-best…
# Loading pipeline components...:  43% 3/7 [00:00<00:00,  6.71it/s]
# Loading weights:   0% 0/517 [00:00<?, ?it/s]
# Loading weights:   0% 1/517 [00:00<00:00, 21620.12it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   0% 1/517 [00:00<00:00, 8473.34it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   0% 2/517 [00:00<00:00, 7281.78it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...

# %%
import subprocess
subprocess.run(['sync'])
# Out:
# CompletedProcess(args=['sync'], returncode=0)

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive
